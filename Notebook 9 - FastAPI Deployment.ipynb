# %% [markdown]
# ### Notebook 9 — FastAPI Deployment (Production Style)

# %% [markdown]
# This notebook converts your recommendation engine into a real API.

# %% [markdown]
# ### Architecture

# %% [raw]
# User
#    ↓
# FastAPI Endpoint
#    ↓
# Load Recommendation Results
#    ↓
# Return JSON Response

# %% [markdown]
# ### Install Dependencies

# %%
# !pip install fastapi uvicorn

# %% [markdown]
# ### Create Project Structure

# %% [raw]
# recommendation_engine/
#
# data/
#     item_df.csv
#     interactions.csv
#     ranking_results.csv
#     final_recommendations.csv
#
# app.py

# %% [markdown]
# ### Create app.py
#
# Create a file named: app.py

# %%
from fastapi import FastAPI
import pandas as pd

app = FastAPI(
    title = "LLM Recommendation Engine"
)

# Load Recommendations
recommendations_df = pd.read_csv("data/final_recommendations.csv")

@app.get("/")

def home():
    return {
        "message": "Recommendation Engine API Running"
    }

@app.get("/recommend/{user_id}")
def recommend(user_id: int):

    recommendations = (
        recommendations_df
        .head(10)
        [
            [
                "title",
                "category",
                "rank_score",
                "explanation"
            ]
        ]
        .to_dict(orient="records")
    )

    return {
        "user_id":user_id,
        "recommendations":recommendations
    }

# %% [markdown]
# ### Run Server
